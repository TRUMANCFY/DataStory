# %%
import pandas as pd

# %%
keywords_20 = pd.read_csv('key_words_top20.csv')

# %%
list(keywords_20['Keywords'])
# Out:
# ['trump',
#  'clinton',
#  'game',
#  'police',
#  'say',
#  'comment',
#  'school',
#  'woman',
#  'yard',
#  'student',
#  'election',
#  'officer',
#  'percent',
#  'republican',
#  'cub',
#  'company',
#  'hurricane',
#  'child',
#  'city',
#  'voter']

# %%
list(keywords_20['Frequency'])
# Out:
# [994,
#  453,
#  432,
#  396,
#  274,
#  260,
#  249,
#  236,
#  218,
#  208,
#  206,
#  198,
#  167,
#  163,
#  160,
#  157,
#  157,
#  157,
#  150,
#  145]

# %%
keywords_top20_08 = pd.read_csv('key_words_top20_08.csv')

# %%
list(keywords_top20_08['Keywords'])
# Out:
# ['trump',
#  'police',
#  'comment',
#  'clinton',
#  'school',
#  'say',
#  'game',
#  'student',
#  'officer',
#  'season',
#  'woman',
#  'child',
#  'percent',
#  'rio',
#  'city',
#  'company',
#  'olympic',
#  'campaign',
#  'county',
#  'film']

# %%
keywords_top20_08
# Out:
#     Keywords  Frequency
# 0      trump        687
# 1     police        388
# 2    comment        329
# 3    clinton        328
# 4     school        263
# 5        say        254
# 6       game        246
# 7    student        200
# 8    officer        178
# 9     season        153
# 10     woman        150
# 11     child        148
# 12   percent        135
# 13       rio        129
# 14      city        129
# 15   company        116
# 16   olympic        116
# 17  campaign        113
# 18    county        113
# 19      film        113

# %%
list(keywords_top20_08['Frequency'])
# Out:
# [687,
#  388,
#  329,
#  328,
#  263,
#  254,
#  246,
#  200,
#  178,
#  153,
#  150,
#  148,
#  135,
#  129,
#  129,
#  116,
#  116,
#  113,
#  113,
#  113]

# %%
keywords_top20_09 = pd.read_csv('key_words_top20_09.csv')

# %%
list(keywords_top20_09['Keywords'])
# Out:
# ['trump',
#  'police',
#  'clinton',
#  'comment',
#  'game',
#  'school',
#  'say',
#  'student',
#  'officer',
#  'child',
#  'percent',
#  'bank',
#  'woman',
#  'yard',
#  'season',
#  'film',
#  'charlotte',
#  'city',
#  'scott',
#  'debate']

# %%
mediatopics = pd.read_csv('top30media_freq.csv')

# %%
mediatopics.drop(['unknown', 'date', 'country', 'website', 'title'], axis=1, inplace=True)

# %%
mediatopics
# Out:
#                 media     id
# 0   Houston Chronicle    133
# 1            Newsweek    206
# 2      New York Times    242
# 3                VICE    402
# 4      Breitbart News    546
# 5            Politico    739
# 6         Daily Beast    750
# 7        The Atlantic   1093
# 8     Washington Post   1556
# 9      Slate Magazine   1916
# 10            Reuters   2313
# 11             Quartz   2627
# 12                CNN   2783
# 13      New York Post   2794
# 14               TIME   3795
# 15          USA TODAY   4338
# 16                NPR   4694
# 17    Huffington Post   5190
# 18           ABC News   5745
# 19  Los Angeles Times   6607
# 20           CBS News   6752
# 21           NBC News   8271
# 22           Fox News  11641

# %%
list(mediatopics['media'])[::-1]
# Out:
# ['Fox News',
#  'NBC News',
#  'CBS News',
#  'Los Angeles Times',
#  'ABC News',
#  'Huffington Post',
#  'NPR',
#  'USA TODAY',
#  'TIME',
#  'New York Post',
#  'CNN',
#  'Quartz',
#  'Reuters',
#  'Slate Magazine',
#  'Washington Post',
#  'The Atlantic',
#  'Daily Beast',
#  'Politico',
#  'Breitbart News',
#  'VICE',
#  'New York Times',
#  'Newsweek',
#  'Houston Chronicle']

# %%
list(mediatopics['id'])[::-1]
# Out:
# [11641,
#  8271,
#  6752,
#  6607,
#  5745,
#  5190,
#  4694,
#  4338,
#  3795,
#  2794,
#  2783,
#  2627,
#  2313,
#  1916,
#  1556,
#  1093,
#  750,
#  739,
#  546,
#  402,
#  242,
#  206,
#  133]

# %%
mediatrump1610 = pd.read_csv('trump_media_top30_1610.csv')

# %%
list(mediatrump1610['media'])
# Out:
# ['ABC News',
#  'CBS News',
#  'CNN',
#  'Fox News',
#  'Huffington Post',
#  'Los Angeles Times',
#  'NBC News',
#  'Politico',
#  'Slate Magazine',
#  'The Atlantic',
#  'USA TODAY',
#  'Washington Post']

# %%
list(mediatrump1610['pos'])
# Out:
# [0.3888888888888889,
#  0.1176470588235294,
#  0.21052631578947367,
#  0.21052631578947367,
#  0.45,
#  0.2972972972972973,
#  0.3414634146341464,
#  0.3225806451612903,
#  0.2222222222222222,
#  0.07692307692307693,
#  0.07142857142857142,
#  0.3404255319148936]

# %%
list(mediatrump1610['neg'])
# Out:
# [0.3055555555555556,
#  0.5882352941176471,
#  0.3157894736842105,
#  0.5789473684210527,
#  0.25,
#  0.16216216216216214,
#  0.2926829268292683,
#  0.0967741935483871,
#  0.4444444444444444,
#  0.2307692307692308,
#  0.14285714285714285,
#  0.1276595744680851]

# %%
list(mediatrump1610['neu'])
# Out:
# [0.3055555555555556,
#  0.2941176470588235,
#  0.4736842105263158,
#  0.21052631578947367,
#  0.30000000000000004,
#  0.5405405405405405,
#  0.3658536585365853,
#  0.5806451612903226,
#  0.33333333333333337,
#  0.6923076923076923,
#  0.7857142857142858,
#  0.5319148936170213]

# %%
fox_daily = pd.read_csv('Fox_10_daily.csv')

# %%
fox_daily
# Out:
#     Unnamed: 0  Unnamed: 0.1        id  unknown      date country     media  \
# 0           44        309985  14752920      420  16-10-07      US  Fox News
# 1           81        311192  14776151      426  16-10-09      US  Fox News
# 2           87        311353  14778721      417  16-10-09      US  Fox News
# 3          133        313419  14833865      537  16-10-12      US  Fox News
# 4          137        314006  14839477     1056  16-10-13      US  Fox News
# 5          147        314413  14846256      328  16-10-13      US  Fox News
# 6          153        313904  14849153      900  16-10-13      US  Fox News
# 7          179        315743  14874107     1417  16-10-15      US  Fox News
# 8          182        315788  14874779      674  16-10-15      US  Fox News
# 9          187        316010  14879740      406  16-10-15      US  Fox News
# 10         218        319283  14938231      738  16-10-19      US  Fox News
# ...

# %%
keywords_09 = pd.read_csv('trump_09_freq.csv')

# %%
list(keywords_09['media'])
# Out:
# ['ABC News',
#  'CBS News',
#  'CNN',
#  'Fox News',
#  'Huffington Post',
#  'Los Angeles Times',
#  'NPR',
#  'New York Post',
#  'Newsweek',
#  'Politico',
#  'Quartz',
#  'Slate Magazine',
#  'TIME',
#  'The Atlantic',
#  'USA TODAY',
#  'Washington Post']

# %%
list(keywords_09['neu'])
# Out:
# [0.3478260869565218,
#  0.5,
#  0.38461538461538464,
#  5.551115123125783e-17,
#  0.30000000000000004,
#  0.475,
#  0.5,
#  0.0,
#  0.5,
#  0.48,
#  0.5,
#  0.2142857142857143,
#  0.5,
#  0.6470588235294117,
#  0.09999999999999998,
#  0.4901960784313726]

# %%
clinton = pd.read_csv('data_clinton.csv')

# %%
clinton
# Out:
#                 media                                           polarity  \
# 0            ABC News  [ 0.03333333 -0.23809524 -0.66666667  1.      ...
# 1            CBS News  [ 0.          0.8         0.55        0.25    ...
# 2                 CNN  [ 0.3        -0.16666667  0.34299517  0.14    ...
# 3            Fox News  [ 0.38636364  0.625       0.66666667 -0.412280...
# 4     Huffington Post  [ 0.4        -0.53846154 -0.65277778  1.      ...
# 5   Los Angeles Times  [ 0.15119363  0.58823529  0.10784314  0.440740...
# 6                 NPR  [ 0.8        -0.025       0.08333333  1.      ...
# 7       New York Post  [ 0.          0.91666667 -0.25       -0.083333...
# 8            Politico  [ 0.52517007  0.45454545  0.5         0.416666...
# 9              Quartz  [ 0.7         0.         -0.03333333  0.8     ...
# 10            Reuters  [0.18181818 0.7        0.5        0.55555556 0...
# 11     Slate Magazine  [-0.2         0.22857143  0.75        0.3     ...
# ...

# %%
list(clinton['media'])
# Out:
# ['ABC News',
#  'CBS News',
#  'CNN',
#  'Fox News',
#  'Huffington Post',
#  'Los Angeles Times',
#  'NPR',
#  'New York Post',
#  'Politico',
#  'Quartz',
#  'Reuters',
#  'Slate Magazine',
#  'TIME',
#  'The Atlantic',
#  'USA TODAY',
#  'Washington Post']

# %%
trump = pd.read_csv('data_trump.csv')

# %%
trump_clinton = trump.merge(clinton, on='media')

# %%
list(trump_clinton['media'])
# Out:
# ['ABC News',
#  'CBS News',
#  'CNN',
#  'Fox News',
#  'Huffington Post',
#  'Los Angeles Times',
#  'NPR',
#  'New York Post',
#  'Politico',
#  'Quartz',
#  'Reuters',
#  'Slate Magazine',
#  'TIME',
#  'The Atlantic',
#  'USA TODAY',
#  'Washington Post']

# %%
list(trump_clinton['neu_y'])
# Out:
# [0.3,
#  0.4,
#  0.5714285714285714,
#  0.11428571428571427,
#  0.3529411764705881,
#  0.4933333333333333,
#  0.3333333333333333,
#  0.20833333333333345,
#  0.4626865671641791,
#  0.375,
#  0.2,
#  0.5263157894736843,
#  0.2666666666666667,
#  0.5789473684210527,
#  0.3142857142857143,
#  0.5]

# %%
repub = pd.read_csv('data_republic.csv')

# %%
trump_repub = trump.merge(repub, on='media')

# %%
list(trump_repub['media'])
# Out:
# ['ABC News',
#  'CBS News',
#  'CNN',
#  'Fox News',
#  'Huffington Post',
#  'Los Angeles Times',
#  'NPR',
#  'New York Post',
#  'Politico',
#  'Quartz',
#  'Reuters',
#  'Slate Magazine',
#  'TIME',
#  'The Atlantic',
#  'USA TODAY',
#  'Washington Post']

# %%
list(trump_repub['neg_y'])
# Out:
# [0.5384615384615384,
#  0.33333333333333337,
#  0.5,
#  0.1428571428571429,
#  0.4615384615384616,
#  0.5,
#  0.4166666666666667,
#  0.5,
#  0.4242424242424242,
#  0.6,
#  0.4285714285714286,
#  0.2666666666666667,
#  0.22222222222222227,
#  0.4,
#  0.4210526315789474,
#  0.5090909090909091]
